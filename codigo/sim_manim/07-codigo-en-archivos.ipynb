# %%
from manim import *

config.media_width = "100%"
_RV = "-v WARNING -qm --progress_bar None --disable_caching Example"
_RI = "-v WARNING -s --progress_bar None --disable_caching Example"
# Out:
# Manim Community v0.17.2

# %%
from scipy import integrate
import numdifftools as nd

import matplotlib.pyplot as plt

# %%
# %run ../../dipolo_electrico.py

# %%
# %run ../../generadores_campo.py

# %% [markdown]
# ### $E\approx 3.2\times 10^{-5}$ generado por 1 carga puntual, $\theta_0=7\pi/12$, durante $30$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(pos=np.array([-1, 0, 0]), radio=1, q=2e-14),
]

dipolo = DipoloElectrico2D(7*PI/12, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30,
                           fields=fields,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 14:30:43.671038 [h:mm:ss.μs]
#
# theta = 1.832595714594046
# self.pos[0] = 1
# l = [-3.62346664e-08  1.35229616e-07  0.00000000e+00]
# p = [-5.79754662e-27  2.16367385e-26  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [3.21636018e-05 1.60818009e-05 0.00000000e+00]
# tau = -7.891504314956578e-31
# dE_r = [[-2.25145213e-05 -1.92981611e-05  0.00000000e+00]
#  [-1.92981611e-05  6.43272036e-06  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.60818009e-05]]
# alpha = -4.026277714311063
# a_x = -2.8702027804437495e-15
# ------------
# cantidad puntos = 902
# [theta, omega] =  [1.832595714594046, 0.0]
# Tiempo de ejecución: 0:00:04.141004 [h:mm:ss.μs]
# CPU times: total: 3.86 s
# Wall time: 4.14 s

# %% [markdown]
# ### $E\approx 6.4\times 10^{-5}$ generado por 1 carga puntual, $\theta_0=\pi/4$ (no hay oscilación), durante $30$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(pos=np.array([0, 0, 0]), radio=1, q=2e-14),
]

dipolo = DipoloElectrico2D(PI/4, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30,
                           fields=fields,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 14:30:47.863905 [h:mm:ss.μs]
#
# theta = 0.7853981633974483
# self.pos[0] = 1
# l = [9.89949495e-08 9.89949495e-08 0.00000000e+00]
# p = [1.58391919e-26 1.58391919e-26 0.00000000e+00]
# I = 1.9600000037209575e-31
# E = [6.35688996e-05 6.35688996e-05 0.00000000e+00]
# tau = 0.0
# dE_r = [[-3.17844498e-05 -9.53533494e-05  0.00000000e+00]
#  [-9.53533494e-05 -3.17844498e-05  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  6.35688996e-05]]
# alpha = 0.0
# a_x = -2.013760001911279e-14
# ------------
# cantidad puntos = 902
# [theta, omega] =  [0.7853981633974483, 0.0]
# Tiempo de ejecución: 0:00:00.754979 [h:mm:ss.μs]
# CPU times: total: 703 ms
# Wall time: 758 ms

# %% [markdown]
# ### $E\approx 6.7\times 10^{8}$ generado por 1 carga puntual, $\theta_0=5\pi/4$ (no hay oscilación), durante $10$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(pos=np.array([0, 0, 0]), radio=1, q=2.1e-1),
]

dipolo = DipoloElectrico2D(5*PI/4, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=10,
                           fps=30,
                           fields=fields,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 14:30:48.635840 [h:mm:ss.μs]
#
# theta = 3.9269908169872414
# self.pos[0] = 1
# l = [-9.89949495e-08 -9.89949495e-08  0.00000000e+00]
# p = [-1.58391919e-26 -1.58391919e-26  0.00000000e+00]
# I = 1.9600000037209575e-31
# E = [6.67473446e+08 6.67473446e+08 0.00000000e+00]
# tau = 0.0
# dE_r = [[-3.33736723e+08 -1.00121017e+09  0.00000000e+00]
#  [-1.00121017e+09 -3.33736723e+08  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  6.67473446e+08]]
# alpha = 0.0
# a_x = 0.21144480020071468
# ------------
# cantidad puntos = 302
# [theta, omega] =  [3.9269908169872414, 0.0]
# Tiempo de ejecución: 0:00:00.771936 [h:mm:ss.μs]
# CPU times: total: 781 ms
# Wall time: 775 ms

# %% [markdown]
# ### $E\approx -5.6\times 10^{-5}$ generado por 4 cargas puntuales, $\theta_0=7\pi/12$, durante $30$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(q_draw=-1, radio=0.2, q=1.6e-14),
    CargaPuntual2D(pos=np.array([5, 2, 0]), radio=1, q=1.6e-14),
    CargaPuntual2D(pos=np.array([-3, -3, 0]), q_draw=-1, q=1.6e-14),
    CargaPuntual2D(pos=np.array([-4, 1, 0]), q=1.6e-14)
]

dipolo = DipoloElectrico2D(7*PI/12, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30,
                           fields=fields,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 14:30:49.448666 [h:mm:ss.μs]
#
# theta = 1.832595714594046
# self.pos[0] = 1
# l = [-3.62346664e-08  1.35229616e-07  0.00000000e+00]
# p = [-5.79754662e-27  2.16367385e-26  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [-5.64885116e-05 -5.60857014e-05  0.00000000e+00]
# tau = 1.5473866218885668e-30
# dE_r = [[ 1.97812938e-05  7.60260293e-05  0.00000000e+00]
#  [ 7.60260293e-05  2.86655804e-05  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -4.84468742e-05]]
# alpha = 7.8948297086083485
# a_x = 1.5302723425297388e-14
# ------------
# cantidad puntos = 902
# [theta, omega] =  [1.832595714594046, 0.0]
# Tiempo de ejecución: 0:00:11.303296 [h:mm:ss.μs]
# CPU times: total: 11.3 s
# Wall time: 11.3 s

# %% [markdown]
# ### $E\approx 1.6\times 10^{-5}$ generado por un par de placas paralelas, $\theta_0=\pi/4$ (no hay desplazamiento), durante $30$ segundos

# %%
# %%time

fields = [
    Placas2D(E=1.6e-5)
]


dipolo = DipoloElectrico2D(PI/4, 
                           pos_draw=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30, 
                           pos=np.array([-3, 0, 0]),
                           fields=fields,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 14:31:00.781885 [h:mm:ss.μs]
#
# theta = 0.7853981633974483
# self.pos[0] = -3
# l = [9.89949491e-08 9.89949494e-08 0.00000000e+00]
# p = [1.58391919e-26 1.58391919e-26 0.00000000e+00]
# I = 1.959999995266091e-31
# E = [1.6e-05 0.0e+00 0.0e+00]
# tau = -2.5342707037725864e-31
# dE_r = [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# alpha = -1.2929952601497492
# a_x = 0.0
# ------------
# cantidad puntos = 902
# [theta, omega] =  [0.7853981633974483, 0.0]
# Tiempo de ejecución: 0:01:02.522799 [h:mm:ss.μs]
# CPU times: total: 1min 2s
# Wall time: 1min 2s

# %% [markdown]
# ### $E\approx -5\times 10^{2}$ generado por 4 cargas puntuales, $\theta_0=7\pi/12$, durante $0.3$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(q_draw=-1, q=1.6e-7),
    CargaPuntual2D(pos=np.array([5, 2, 0]), q=1.6e-7),
    CargaPuntual2D(pos=np.array([-3, -3, 0]), q_draw=-1, q=1.6e-7),
    CargaPuntual2D(pos=np.array([-4, 1, 0]), q=1.6e-7)
]


dipolo = DipoloElectrico2D(7*PI/12,
                           pos_draw=np.array([1, 1, 0]), 
                           t_end=0.3,  
                           fps=30, 
                           fields=fields, 
                           pos=np.array([1, 1, 0]),
                           set_time_interval=False,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 14:32:03.329580 [h:mm:ss.μs]
#
# theta = 1.832595714594046
# self.pos[0] = 1
# l = [-3.62346664e-08  1.35229616e-07  0.00000000e+00]
# p = [-5.79754662e-27  2.16367385e-26  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [-564.8851158  -560.85701408    0.        ]
# tau = 1.5473866218885666e-23
# dE_r = [[ 197.81293801  760.26029323    0.        ]
#  [ 760.26029323  286.65580423    0.        ]
#  [   0.            0.         -484.46874224]]
# alpha = 78948297.08608347
# a_x = 1.5302723425300137e-07
# ------------
# cantidad puntos = 11.0
# [theta, omega] =  [1.832595714594046, 0.0]
# Tiempo de ejecución: 0:05:41.986172 [h:mm:ss.μs]
# CPU times: total: 5min 41s
# Wall time: 5min 41s

# %% [markdown]
# ### $E\approx -5\times 10^{5}$ generado por 4 cargas puntuales, $\theta_0=7\pi/12$, durante $0.03$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(q_draw=-1, q=1.6e-4),
    CargaPuntual2D(pos=np.array([5, 2, 0]), q=1.6e-4),
    CargaPuntual2D(pos=np.array([-3, -3, 0]), q_draw=-1, q=1.6e-4),
    CargaPuntual2D(pos=np.array([-4, 1, 0]), q=1.6e-4)
]


dipolo = DipoloElectrico2D(7*PI/12,                                   # angle = PI/3 + PI/4
                           pos_draw=np.array([1, 1, 0]), 
                           t_end=0.03,  
                           fps=30, 
                           fields=fields, 
                           pos=np.array([1, 1, 0]),
                           set_time_interval=False,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 14:37:45.347666 [h:mm:ss.μs]
#
# theta = 1.832595714594046
# self.pos[0] = 1
# l = [-3.62346664e-08  1.35229616e-07  0.00000000e+00]
# p = [-5.79754662e-27  2.16367385e-26  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [-564885.11579717 -560857.01408207       0.        ]
# tau = 1.5473866218885672e-20
# dE_r = [[ 197812.9380126   760260.29323263       0.        ]
#  [ 760260.29323261  286655.80423188       0.        ]
#  [      0.               0.         -484468.74224458]]
# alpha = 78948297086.0835
# a_x = 0.00015302723425298533
# ------------
# cantidad puntos = 2.9
# [theta, omega] =  [1.832595714594046, 0.0]
# Tiempo de ejecución: 0:21:24.210840 [h:mm:ss.μs]
# CPU times: total: 21min 20s
# Wall time: 21min 24s

# %%
dipolo.zoom_plot(1500, 1900)

# %% [markdown]
# ### $E\approx -5\times 10^{5}$ generado por 4 cargas puntuales, $\theta_0=7\pi/12$, durante $0.1$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(q_draw=-1, q=1.6e-4),
    CargaPuntual2D(pos=np.array([5, 2, 0]), q=1.6e-4),
    CargaPuntual2D(pos=np.array([-3, -3, 0]), q_draw=-1, q=1.6e-4),
    CargaPuntual2D(pos=np.array([-4, 1, 0]), q=1.6e-4)
]


dipolo = DipoloElectrico2D(7*PI/12,                                   # angle = PI/3 + PI/4
                           pos_draw=np.array([1, 1, 0]), 
                           t_end=0.1,  
                           fps=30, 
                           fields=fields, 
                           pos=np.array([1, 1, 0]),
                           set_time_interval=False,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 14:59:09.881642 [h:mm:ss.μs]
#
# theta = 1.832595714594046
# self.pos[0] = 1
# l = [-3.62346664e-08  1.35229616e-07  0.00000000e+00]
# p = [-5.79754662e-27  2.16367385e-26  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [-564885.11579717 -560857.01408207       0.        ]
# tau = 1.5473866218885672e-20
# dE_r = [[ 197812.9380126   760260.29323263       0.        ]
#  [ 760260.29323261  286655.80423188       0.        ]
#  [      0.               0.         -484468.74224458]]
# alpha = 78948297086.0835
# a_x = 0.00015302723425298533
# ------------
# cantidad puntos = 5.0
# [theta, omega] =  [1.832595714594046, 0.0]
# Tiempo de ejecución: 1:00:20.328487 [h:mm:ss.μs]
# CPU times: total: 1h 15s
# Wall time: 1h 20s

# %% [markdown]
# ### $E\approx 3.2\times 10^{-5}$ generado por 1 carga puntual, $\theta_0=13\pi/12$, durante $30$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(pos=np.array([-1, 0, 0]), radio=1, q=2e-14),
]

dipolo = DipoloElectrico2D(13*PI/12, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30,
                           fields=fields,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 15:59:30.226003 [h:mm:ss.μs]
#
# theta = 3.4033920413889427
# self.pos[0] = 1
# l = [-1.35229616e-07 -3.62346664e-08  0.00000000e+00]
# p = [-2.16367385e-26 -5.79754662e-27  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [3.21636018e-05 1.60818009e-05 0.00000000e+00]
# tau = -1.6148773968157333e-31
# dE_r = [[-2.25145213e-05 -1.92981611e-05  0.00000000e+00]
#  [-1.92981611e-05  6.43272036e-06  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.60818009e-05]]
# alpha = -0.8239170397234493
# a_x = 5.990227972601085e-15
# ------------
# cantidad puntos = 902
# [theta, omega] =  [3.4033920413889427, 0.0]
# Tiempo de ejecución: 0:00:04.128379 [h:mm:ss.μs]
# CPU times: total: 4.12 s
# Wall time: 4.13 s

# %%
#for v in dipolo.solution.y[0]:
#    print(f"{v:.50f}")

# %% [markdown]
# ### $E\approx 3.2\times 10^{-5}$ generado por 1 carga puntual, $\theta_0=13\pi/12$, solo ángulo, durante $30$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(pos=np.array([-1, 0, 0]), radio=1, q=2e-14),
]

dipolo = DipoloElectrico2D(13*PI/12, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30,
                           fields=fields,
                           resolver_desplazamiento=False,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 15:59:34.390247 [h:mm:ss.μs]
#
# theta = 3.4033920413889427
# self.pos[0] = 1
# l = [-1.35229616e-07 -3.62346664e-08  0.00000000e+00]
# p = [-2.16367385e-26 -5.79754662e-27  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [3.21636018e-05 1.60818009e-05 0.00000000e+00]
# tau = -1.6148773968157333e-31
# dE_r = [[-2.25145213e-05 -1.92981611e-05  0.00000000e+00]
#  [-1.92981611e-05  6.43272036e-06  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.60818009e-05]]
# alpha = -0.8239170397234493
# a_x = 5.990227972601085e-15
# ------------
# cantidad puntos = 902
# [theta, omega] =  [3.4033920413889427, 0.0]
# Tiempo de ejecución: 0:00:00.584437 [h:mm:ss.μs]
# CPU times: total: 609 ms
# Wall time: 588 ms

# %% [markdown]
# ### $E\approx 3.2\times 10^{-5}$ generado por 1 carga puntual, $\theta_0=13\pi/12$, solo desplazamiento, durante $30$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(pos=np.array([-1, 0, 0]), radio=1, q=2e-14),
]

dipolo = DipoloElectrico2D(13*PI/12, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30,
                           fields=fields,
                           resolver_angulo=False,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 15:59:34.998619 [h:mm:ss.μs]
#
# theta = 3.4033920413889427
# self.pos[0] = 1
# l = [-1.35229616e-07 -3.62346664e-08  0.00000000e+00]
# p = [-2.16367385e-26 -5.79754662e-27  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [3.21636018e-05 1.60818009e-05 0.00000000e+00]
# tau = -1.6148773968157333e-31
# dE_r = [[-2.25145213e-05 -1.92981611e-05  0.00000000e+00]
#  [-1.92981611e-05  6.43272036e-06  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.60818009e-05]]
# alpha = -0.8239170397234493
# a_x = 5.990227972601085e-15
# ------------
# cantidad puntos = 902
# [theta, omega] =  [3.4033920413889427, 0.0]
# Tiempo de ejecución: 0:00:00.549738 [h:mm:ss.μs]
# CPU times: total: 578 ms
# Wall time: 552 ms

# %%
#for v in dipolo.solution.y[0]:
#    print(f"{v:.50f}")

# %% [markdown]
# ### $E\approx 3.2\times 10^{7}$ generado por 1 carga puntual, $\theta_0=13\pi/12$, solo desplazamiento, durante $30$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(pos=np.array([-1, 0, 0]), radio=1, q=2e-2),
]

dipolo = DipoloElectrico2D(13*PI/12, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30,
                           fields=fields,
                           resolver_angulo=False,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 15:59:35.579237 [h:mm:ss.μs]
#
# theta = 3.4033920413889427
# self.pos[0] = 1
# l = [-1.35229616e-07 -3.62346664e-08  0.00000000e+00]
# p = [-2.16367385e-26 -5.79754662e-27  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [32163601.78835697 16081800.89417849        0.        ]
# tau = -1.6148773968157333e-19
# dE_r = [[-22514521.25185154 -19298161.07301506         0.        ]
#  [-19298161.07301422   6432720.35766977         0.        ]
#  [        0.                 0.          16081800.89417848]]
# alpha = -823917039723.4493
# a_x = 0.005990227972602526
# ------------
# cantidad puntos = 902
# [theta, omega] =  [3.4033920413889427, 0.0]
# Tiempo de ejecución: 0:00:00.592192 [h:mm:ss.μs]
# CPU times: total: 594 ms
# Wall time: 594 ms

# %%
# %%time

fields = [
    CargaPuntual2D(pos=np.array([-1, 0, 0]), radio=1, q=2e-2),
]

dipolo = DipoloElectrico2D(13*PI/12, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30,
                           fields=fields,
                           solucionador='myRK45',                      # <--- con mi versión, sale igual
                           resolver_angulo=False,                      # <--- también sin ángulo
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 15:59:36.204341 [h:mm:ss.μs]
#
# theta = 3.4033920413889427
# self.pos[0] = 1
# l = [-1.35229616e-07 -3.62346664e-08  0.00000000e+00]
# p = [-2.16367385e-26 -5.79754662e-27  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [32163601.78835697 16081800.89417849        0.        ]
# tau = -1.6148773968157333e-19
# dE_r = [[-22514521.25185154 -19298161.07301506         0.        ]
#  [-19298161.07301422   6432720.35766977         0.        ]
#  [        0.                 0.          16081800.89417848]]
# alpha = -823917039723.4493
# a_x = 0.005990227972602526
# ------------
# cantidad puntos = 902
# [theta, omega] =  [3.4033920413889427, 0.0]
# Tiempo de ejecución: 0:00:16.361355 [h:mm:ss.μs]
# CPU times: total: 16.4 s
# Wall time: 16.4 s

# %% [markdown]
# ### $E\approx 3.2\times 10^{7}$ generado por 1 carga puntual, $\theta_0=13\pi/12$, durante $30$ segundos

# %%
# %%time

fields = [
    CargaPuntual2D(pos=np.array([-1, 0, 0]), radio=1, q=2e-2),
]

dipolo = DipoloElectrico2D(13*PI/12, 
                           pos_draw=np.array([1, 1, 0]),
                           pos=np.array([1, 1, 0]),
                           t_end=30,
                           fps=30,
                           fields=fields,
                           solucionador='myRK45',
                           resolver_angulo=True,
                           logging=True,
                           plots=True)
# Out:
# Inicio de ejecución: 2023-04-28 15:59:52.590630 [h:mm:ss.μs]
#
# theta = 3.4033920413889427
# self.pos[0] = 1
# l = [-1.35229616e-07 -3.62346664e-08  0.00000000e+00]
# p = [-2.16367385e-26 -5.79754662e-27  0.00000000e+00]
# I = 1.9599999987350336e-31
# E = [32163601.78835697 16081800.89417849        0.        ]
# tau = -1.6148773968157333e-19
# dE_r = [[-22514521.25185154 -19298161.07301506         0.        ]
#  [-19298161.07301422   6432720.35766977         0.        ]
#  [        0.                 0.          16081800.89417848]]
# alpha = -823917039723.4493
# a_x = 0.005990227972602526
# ------------
# cantidad puntos = 902
# [theta, omega] =  [3.4033920413889427, 0.0]
# Tiempo de ejecución: 0:00:17.017540 [h:mm:ss.μs]
# CPU times: total: 17 s
# Wall time: 17 s
